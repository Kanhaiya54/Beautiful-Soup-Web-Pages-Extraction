# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import csv
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pages = []
for i in range(1, 6):
    url = 'https://www.top500.org/list/2018/06/?page=' + str(i)
    pages.append(url)
file=open("output.txt","a+")
data=[]
for x in pages:
    results=requests.get(x)
    c=results.content
    soup=BeautifulSoup(c)
    bs=soup.find("table",{"class":"table table-condensed table-striped"})
    tr=bs.findAll("tr")
    
    for rows in tr:
        data_in_row=[]
        td=rows.findAll("td")
        for each_td in td:
            text=each_td.findAll(text=True)
            text = [x for x in text if x !='\n']
            data_in_row.extend(text)
            file.write(str(text)+"\n")
        data.append(data_in_row)        
#url=requests.get("")
#c=url.content
# Out:
# C:\Users\mitta\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\mitta\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
data
# Out:
# [[],
#  ['1',
#   'DOE/SC/Oak Ridge National Laboratory',
#   'United States',
#   'Summit',
#   ' - IBM Power System AC922, IBM POWER9 22C 3.07GHz, NVIDIA Volta GV100, Dual-rail Mellanox EDR Infiniband\n                    ',
#   'IBM',
#   '2,282,544',
#   '122,300.0',
#   '187,659.3',
#   '8,806'],
#  ['2',
#   'National Supercomputing Center in Wuxi',
#   'China',
#   'Sunway TaihuLight',
#   ' - Sunway MPP, Sunway SW26010 260C 1.45GHz, Sunway\n                    ',
#   'NRCPC',
#   '10,649,600',
#   '93,014.6',
#   '125,435.9',
#   '15,371'],
#  ['3',
#   'DOE/NNSA/LLNL',
#   'United States',
#   'Sierra',
#   ' - IBM Power System S922LC, IBM POWER9 22C 3.1GHz, NVIDIA Volta GV100, Dual-rail Mellanox EDR Infiniband\n                    ',
#   'IBM',
#   '1,572,480',
#   '71,610.0',
#   '119,193.6'],
#  ['4',
#   'National Super Computer Center in Guangzhou',
#   'China',
#   'Tianhe-2A',
#   ' - TH-IVB-FEP Cluster, Intel Xeon E5-2692v2 12C 2.2GHz, TH Express-2, Matrix-2000\n                    ',
#   'NUDT',
#   '4,981,760',
#   '61,444.5',
#   '100,678.7',
#   '18,482'],
#  ['5',
#   'National Institute of Advanced Industrial Science and Technology (AIST)',
#   'Japan',
#   'AI Bridging Cloud Infrastructure (ABCI)',
#   ' - PRIMERGY CX2550 M4, Xeon Gold 6148 20C 2.4GHz, NVIDIA Tesla V100 SXM2, Infiniband EDR\n                    ',
#   'Fujitsu',
#   '391,680',
#   '19,880.0',
#   '32,576.6',
#   '1,649'],
#  ['6',
#   'Swiss National Supercomputing Centre (CSCS)',
#   'Switzerland',
#   'Piz Daint',
#   ' - Cray XC50, Xeon E5-2690v3 12C 2.6GHz, Aries interconnect , NVIDIA Tesla P100\n                    ',
#   'Cray Inc.',
#   '361,760',
#   '19,590.0',
#   '25,326.3',
#   '2,272'],
#  ['7',
#   'DOE/SC/Oak Ridge National Laboratory',
#   'United States',
#   'Titan',
#   ' - Cray XK7, Opteron 6274 16C 2.200GHz, Cray Gemini interconnect, NVIDIA K20x\n                    ',
#   'Cray Inc.',
#   '560,640',
#   '17,590.0',
#   '27,112.5',
#   '8,209'],
#  ['8',
#   'DOE/NNSA/LLNL',
#   'United States',
#   'Sequoia',
#   ' - BlueGene/Q, Power BQC 16C 1.60 GHz, Custom\n                    ',
#   'IBM',
#   '1,572,864',
#   '17,173.2',
#   '20,132.7',
#   '7,890'],
#  ['9',
#   'DOE/NNSA/LANL/SNL',
#   'United States',
#   'Trinity',
#   ' - Cray XC40, Intel Xeon Phi 7250 68C 1.4GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '979,968',
#   '14,137.3',
#   '43,902.6',
#   '3,844'],
#  ['10',
#   'DOE/SC/LBNL/NERSC',
#   'United States',
#   'Cori',
#   ' - Cray XC40, Intel Xeon Phi 7250 68C 1.4GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '622,336',
#   '14,014.7',
#   '27,880.7',
#   '3,939'],
#  ['11',
#   'Korea Institute of Science and Technology Information',
#   'Korea, South',
#   'Nurion',
#   ' - Cray CS500, Intel Xeon Phi 7250 68C 1.4GHz, Intel Omni-Path\n                    ',
#   'Cray Inc.',
#   '570,020',
#   '13,929.3',
#   '25,705.9'],
#  ['12',
#   'Joint Center for Advanced High Performance Computing',
#   'Japan',
#   'Oakforest-PACS',
#   ' - PRIMERGY CX1640 M1, Intel Xeon Phi 7250 68C 1.4GHz, Intel Omni-Path\n                    ',
#   'Fujitsu',
#   '556,104',
#   '13,554.6',
#   '24,913.5',
#   '2,719'],
#  ['13',
#   'Eni S.p.A.',
#   'Italy',
#   'HPC4',
#   ' - Proliant DL380 Gen10, Xeon Platinum 8160  24C 2.1GHz, Mellanox InfiniBand EDR, NVIDIA Tesla P100\n                    ',
#   'HPE',
#   '253,600',
#   '12,210.0',
#   '18,621.1',
#   '1,320'],
#  ['14',
#   "Commissariat a l'Energie Atomique (CEA)",
#   'France',
#   'Tera-1000-2',
#   ' - Bull Sequana X1000, Intel Xeon Phi 7250 68C 1.4GHz, Bull BXI 1.2\n                    ',
#   'Bull, Atos Group',
#   '561,408',
#   '11,965.5',
#   '23,396.4',
#   '3,178'],
#  ['15',
#   'Texas Advanced Computing Center/Univ. of Texas',
#   'United States',
#   'Stampede2',
#   ' - PowerEdge C6320P/C6420, Intel Xeon Phi 7250 68C 1.4GHz/Platinum 8160, Intel Omni-Path\n                    ',
#   'Dell EMC',
#   '367,024',
#   '10,680.7',
#   '18,309.2'],
#  ['16',
#   'RIKEN Advanced Institute for Computational Science (AICS)',
#   'Japan',
#   'K computer, SPARC64 VIIIfx 2.0GHz, Tofu interconnect\n                    ',
#   'Fujitsu',
#   '705,024',
#   '10,510.0',
#   '11,280.4',
#   '12,660'],
#  ['17',
#   'DOE/SC/Argonne National Laboratory',
#   'United States',
#   'Mira',
#   ' - BlueGene/Q, Power BQC 16C 1.60GHz, Custom\n                    ',
#   'IBM',
#   '786,432',
#   '8,586.6',
#   '10,066.3',
#   '3,945'],
#  ['18',
#   'CINECA',
#   'Italy',
#   'Marconi Intel Xeon Phi',
#   ' - CINECA Cluster, Lenovo SD530/S720AP, Intel Xeon Phi 7250 68C 1.4GHz/Platinum 8160, Intel Omni-Path\n                    ',
#   'Lenovo',
#   '312,936',
#   '8,413.1',
#   '16,212.9'],
#  ['19',
#   'GSIC Center, Tokyo Institute of Technology',
#   'Japan',
#   'TSUBAME3.0',
#   ' - SGI ICE XA, IP139-SXM2, Xeon E5-2680v4 14C 2.4GHz, Intel Omni-Path, NVIDIA Tesla P100 SXM2\n                    ',
#   'HPE',
#   '135,828',
#   '8,125.0',
#   '12,127.1',
#   '792'],
#  ['20',
#   'United Kingdom Meteorological Office',
#   'United Kingdom',
#   'Cray XC40, Xeon E5-2695v4 18C 2.1GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '241,920',
#   '7,038.9',
#   '8,128.5'],
#  ['21',
#   'DOE/SC/Argonne National Laboratory',
#   'United States',
#   'Theta',
#   ' - Cray XC40, Intel Xeon Phi 7230 64C 1.3GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '280,320',
#   '6,920.9',
#   '11,661.3'],
#  ['22',
#   'Barcelona Supercomputing Center',
#   'Spain',
#   'MareNostrum',
#   ' - Lenovo SD530, Xeon Platinum 8160 24C 2.1GHz, Intel Omni-Path\n                    ',
#   'Lenovo',
#   '153,216',
#   '6,470.8',
#   '10,296.1',
#   '1,632'],
#  ['23',
#   'Forschungszentrum Juelich (FZJ)',
#   'Germany',
#   'JUWELS Module 1',
#   ' - Bull Sequana X1000, Xeon Platinum 8168 24C 2.7GHz, Mellanox EDR InfiniBand/ParTec ParaStation ClusterSuite\n                    ',
#   'Bull, Atos Group',
#   '114,480',
#   '6,177.7',
#   '9,891.1',
#   '1,361'],
#  ['24',
#   'NASA/Ames Research Center/NAS',
#   'United States',
#   'Pleiades',
#   ' - SGI ICE X, Intel Xeon E5-2670/E5-2680v2/E5-2680v3/E5-2680v4  2.6/2.8/2.5/2.4 GHz, Infiniband FDR\n                    ',
#   'HPE',
#   '241,108',
#   '5,951.6',
#   '7,107.1',
#   '4,407'],
#  ['25',
#   'Japan Meteorological Agency',
#   'Japan',
#   'Cray XC50, Xeon Platinum 8160  24C 2.1GHz, Aries interconnect \n                    ',
#   'Cray Inc./Hitachi',
#   '135,792',
#   '5,730.5',
#   '9,125.2',
#   '1,354'],
#  ['26',
#   'Japan Meteorological Agency',
#   'Japan',
#   'Cray XC50, Xeon Platinum 8160  24C 2.1GHz, Aries interconnect \n                    ',
#   'Cray Inc./Hitachi',
#   '135,792',
#   '5,730.5',
#   '9,125.2',
#   '1,354'],
#  ['27',
#   'HLRS - Höchstleistungsrechenzentrum Stuttgart',
#   'Germany',
#   'Hazel Hen',
#   ' - Cray XC40, Xeon E5-2680v3 12C 2.5GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '185,088',
#   '5,640.2',
#   '7,403.5',
#   '3,615'],
#  ['28',
#   'Max-Planck-Gesellschaft MPI/IPP',
#   'Germany',
#   'COBRA',
#   ' - Intel Compute Module HNS2600BP, Xeon Gold 6148 20C 2.4GHz, Intel Omni-Path\n                    ',
#   'Intel',
#   '127,520',
#   '5,612.8',
#   '9,793.5',
#   '1,635'],
#  ['29',
#   'King Abdullah University of Science and Technology',
#   'Saudi Arabia',
#   'Shaheen II',
#   ' - Cray XC40, Xeon E5-2698v3 16C 2.3GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '196,608',
#   '5,537.0',
#   '7,235.2',
#   '2,834'],
#  ['30',
#   'Total Exploration Production',
#   'France',
#   'Pangea',
#   ' - SGI ICE X, Xeon Xeon E5-2670/ E5-2680v3 12C 2.5GHz, Infiniband FDR\n                    ',
#   'HPE',
#   '220,800',
#   '5,283.1',
#   '6,712.3',
#   '4,150'],
#  ['31',
#   'National Center for Atmospheric Research (NCAR)',
#   'United States',
#   'Cheyenne',
#   ' - SGI ICE XA, Xeon E5-2697v4 18C 2.3GHz, Infiniband EDR\n                    ',
#   'HPE',
#   '144,900',
#   '4,788.2',
#   '5,332.3',
#   '1,727'],
#  ['32',
#   'Research Institute for Information Technology, Kyushu University',
#   'Japan',
#   'ITO - Subsystem A',
#   ' - Fujitsu PRIMERGY CX2550/CX2560 M4, Xeon Gold 6154 18C 3GHz, Mellanox InfiniBand EDR\n                    ',
#   'Fujitsu',
#   '72,000',
#   '4,540.7',
#   '6,912.0'],
#  ['33',
#   'DOE/NNSA/LLNL',
#   'United States',
#   'Vulcan',
#   ' - BlueGene/Q, Power BQC 16C 1.600GHz, Custom Interconnect\n                    ',
#   'IBM',
#   '393,216',
#   '4,293.3',
#   '5,033.2',
#   '1,972'],
#  ['34',
#   'CEA/TGCC-GENCI',
#   'France',
#   'JOLIOT-CURIE SKL',
#   ' - Bull Sequana X1000, Xeon Platinum 8168 24C 2.7GHz, Mellanox EDR\n                    ',
#   'Bull, Atos Group',
#   '79,488',
#   '4,065.6',
#   '6,635.5',
#   '917'],
#  ['35',
#   'Petroleum Geo-Services',
#   'United States',
#   'Abel',
#   ' - Cray XC30, Xeon E5-2698v3 16C 2.3GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '145,920',
#   '4,042.5',
#   '5,369.9',
#   '1,800'],
#  ['36',
#   'ECMWF',
#   'United Kingdom',
#   'Cray XC40, Xeon E5-2695v4 18C 2.1GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '126,468',
#   '3,944.7',
#   '4,249.3',
#   '1,897'],
#  ['37',
#   'ECMWF',
#   'United Kingdom',
#   'Cray XC40, Xeon E5-2695v4 18C 2.1GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '126,468',
#   '3,944.7',
#   '4,249.3',
#   '1,897'],
#  ['38',
#   'Forschungszentrum Juelich (FZJ)',
#   'Germany',
#   'JURECA',
#   ' - T-Platforms V-Class/Dell C6320P, E5-2680v3/Phi 7250-F, EDR/Intel Omni-Path/ParTec ParaStation, Tesla K80/K40\n                    ',
#   'T-Platforms, Intel, Dell',
#   '155,150',
#   '3,782.6',
#   '6,563.8',
#   '1,345'],
#  ['39',
#   'Indian Institute of Tropical Meteorology',
#   'India',
#   'Pratyush',
#   ' - Cray XC40, Xeon E5-2695v4 18C 2.1GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '119,232',
#   '3,763.9',
#   '4,006.2',
#   '1,353'],
#  ['40',
#   'Government',
#   'United States',
#   'Cray CS-Storm, Intel Xeon E5-2660v2 10C 2.2GHz, Infiniband FDR, Nvidia K40\n                    ',
#   'Cray Inc.',
#   '72,800',
#   '3,577.0',
#   '6,131.8',
#   '1,499'],
#  ['41',
#   'Government',
#   'United States',
#   'Cray CS-Storm, Intel Xeon E5-2660v2 10C 2.2GHz, Infiniband FDR, Nvidia K40\n                    ',
#   'Cray Inc.',
#   '72,800',
#   '3,577.0',
#   '6,131.8',
#   '1,499'],
#  ['42',
#   'ERDC DSRC',
#   'United States',
#   'ONYX',
#   ' - Cray XC40, Intel Xeon Phi 7230 64C 1.3GHz/Xeon E5-2699v4, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '160,304',
#   '3,409.6',
#   '5,865.5'],
#  ['43',
#   'NASA/Ames Research Center/NAS',
#   'United States',
#   'Electra',
#   ' - HPE SGI 8600, SGI ICE-X, Xeon E5-2680V4/Gold 6148 20C 2.4GHz, Infiniband EDR\n                    ',
#   'HPE',
#   '78,336',
#   '3,328.6',
#   '4,777.6',
#   '980'],
#  ['44',
#   'ERDC DSRC',
#   'United States',
#   'Topaz',
#   ' - SGI ICE X, Xeon E5-2699v3 18C 2.3GHz, Infiniband FDR\n                    ',
#   'HPE',
#   '124,200',
#   '3,318.9',
#   '4,570.6',
#   '5,175'],
#  ['45',
#   'Facebook',
#   'United States',
#   'NVIDIA DGX-1/Relion 2904GT, Xeon E5-2698v4 20C 2.2GHz/ E5-2650v4, Infiniband EDR, NVIDIA Tesla P100/Quadro GP100\n                    ',
#   'Self-made',
#   '60,512',
#   '3,307.0',
#   '4,896.5',
#   '350'],
#  ['46',
#   'NVIDIA Corporation',
#   'United States',
#   'DGX Saturn V',
#   ' - NVIDIA DGX-1, Xeon E5-2698v4 20C 2.2GHz, Infiniband EDR, NVIDIA Tesla P100\n                    ',
#   'Nvidia',
#   '60,512',
#   '3,307.0',
#   '4,896.5',
#   '350'],
#  ['47',
#   'AWE',
#   'United Kingdom',
#   'Damson',
#   ' - Bull Sequana X1000, Xeon E5-2697v4 18C 2.3GHz, Infiniband EDR\n                    ',
#   'Bull, Atos Group',
#   '113,832',
#   '3,243.4',
#   '3,791.6',
#   '1,134'],
#  ['48',
#   'Air Force Research Laboratory',
#   'United States',
#   'Mustang',
#   ' - HPE SGI 8600, Xeon Platinum 8168 24C 2.7GHz, Intel Omni-Path\n                    ',
#   'HPE',
#   '55,296',
#   '3,221.4',
#   '4,777.6'],
#  ['49',
#   'Eni S.p.A.',
#   'Italy',
#   'HPC2',
#   ' - iDataPlex DX360M4, Intel Xeon E5-2680v2  10C 2.8GHz, Infiniband FDR, NVIDIA K20x\n                    ',
#   'IBM',
#   '72,000',
#   '3,188.0',
#   '4,605.0',
#   '1,227'],
#  ['50',
#   'Japan Aerospace eXploration Agency',
#   'Japan',
#   'SORA-MA',
#   ' - Fujitsu PRIMEHPC FX100, SPARC64 XIfx  32C 1.98GHz, Tofu interconnect 2\n                    ',
#   'Fujitsu',
#   '110,160',
#   '3,157.0',
#   '3,481.1',
#   '1,652'],
#  ['51',
#   'Government',
#   'United States',
#   'Cray XC30, Intel Xeon E5-2697v2 12C 2.7GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '225,984',
#   '3,143.5',
#   '4,881.3',
#   '6,328'],
#  ['52',
#   'Air Force Research Laboratory',
#   'United States',
#   'Thunder',
#   ' - SGI ICE X, Xeon E5-2699v3/E5-2697 v3, Infiniband FDR, NVIDIA Tesla K40, Intel Xeon Phi 7120P\n                    ',
#   'HPE',
#   '152,692',
#   '3,126.2',
#   '5,610.5',
#   '4,820'],
#  ['53',
#   'SciNet/University of Toronto/Compute Canada',
#   'Canada',
#   'Niagara',
#   ' - ThinkSystem SD530, Xeon Gold 6148 20C 2.4GHz, Infiniband EDR\n                    ',
#   'Lenovo',
#   '60,000',
#   '3,074.2',
#   '4,608.0',
#   '676'],
#  ['54',
#   'Academic Center for Computing and Media Studies (ACCMS),  Kyoto University',
#   'Japan',
#   'Camphor 2',
#   ' - Cray XC40, Intel Xeon Phi 7250 68C 1.4GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '122,400',
#   '3,057.3',
#   '5,483.5',
#   '748'],
#  ['55',
#   'DKRZ - Deutsches Klimarechenzentrum',
#   'Germany',
#   'Mistral',
#   ' - bullx DLC 720, Xeon E5-2680v3 12C 2.5GHz/E5-2695V4 18C  2.1Ghz, Infiniband FDR\n                    ',
#   'Bull, Atos Group',
#   '99,072',
#   '3,010.7',
#   '3,962.9',
#   '1,116'],
#  ['56',
#   'Information Technology Center, Nagoya University',
#   'Japan',
#   'Fujitsu PRIMEHPC FX100, SPARC64 XIfx 32C 2.2GHz, Tofu interconnect 2\n                    ',
#   'Fujitsu',
#   '92,160',
#   '2,910.0',
#   '3,244.0',
#   '1,382'],
#  ['57',
#   'Leibniz Rechenzentrum',
#   'Germany',
#   'SuperMUC',
#   ' - iDataPlex DX360M4, Xeon E5-2680 8C 2.70GHz, Infiniband FDR\n                    ',
#   'IBM/Lenovo',
#   '147,456',
#   '2,897.0',
#   '3,185.1',
#   '3,423'],
#  ['58',
#   'Leibniz Rechenzentrum',
#   'Germany',
#   'SuperMUC Phase 2',
#   ' - NeXtScale nx360M5, Xeon E5-2697v3 14C 2.6GHz, Infiniband FDR14\n                    ',
#   'Lenovo/IBM',
#   '86,016',
#   '2,813.6',
#   '3,578.3',
#   '1,481'],
#  ['59',
#   'United Kingdom Meteorological Office',
#   'United Kingdom',
#   'Cray XC40, Xeon E5-2695v4 18C 2.1GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '89,856',
#   '2,801.8',
#   '3,019.2',
#   '1,348'],
#  ['60',
#   'United Kingdom Meteorological Office',
#   'United Kingdom',
#   'Cray XC40, Xeon E5-2695v4 18C 2.1GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '89,856',
#   '2,801.8',
#   '3,019.2',
#   '1,348'],
#  ['61',
#   'Rokkasho Fusion Institute, National Institutes for Quantum and Radiological Science and Technology',
#   'Japan',
#   'JFRS-1',
#   ' - Cray XC50, Xeon Gold 6148 20C 2.4GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '54,560',
#   '2,787.1',
#   '4,190.2',
#   '698'],
#  ['62',
#   'GSIC Center, Tokyo Institute of Technology',
#   'Japan',
#   'TSUBAME 2.5',
#   ' - Cluster Platform SL390s G7, Xeon X5670 6C 2.93GHz, Infiniband QDR, NVIDIA K20x\n                    ',
#   'NEC/HPE',
#   '76,032',
#   '2,785.0',
#   '5,735.7',
#   '1,399'],
#  ['63',
#   'Lawrence Livermore National Laboratory',
#   'United States',
#   'LLNL CTS-1 Quartz',
#   ' - Tundra Extreme Scale, Xeon E5-2695v4 18C 2.1GHz, Intel Omni-Path\n                    ',
#   'Penguin Computing, Inc.',
#   '95,472',
#   '2,632.5',
#   '3,207.9',
#   '13,620'],
#  ['64',
#   'Lawrence Livermore National Laboratory',
#   'United States',
#   'LLNL/NNSA CTS-1 Jade',
#   ' - Tundra Extreme Scale, Xeon E5-2695v4 18C 2.1GHz, Intel Omni-Path\n                    ',
#   'Penguin Computing, Inc.',
#   '95,472',
#   '2,632.5',
#   '3,207.9',
#   '13,620'],
#  ['65',
#   'Energy Company (A)',
#   'Italy',
#   'HPC3',
#   ' - Lenovo NeXtScale nx360M5, Xeon E5-2697v4 18C 2.3GHz, Infiniband EDR, NVIDIA Tesla K80\n                    ',
#   'Lenovo',
#   '66,000',
#   '2,592.0',
#   '3,798.6'],
#  ['66',
#   'National Centre for Medium Range Weather Forecasting',
#   'India',
#   'Mihir',
#   ' - Cray XC40, Xeon E5-2695v4 18C 2.1GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '83,592',
#   '2,570.4',
#   '2,808.7',
#   '955'],
#  ['67',
#   'National Supercomputing Center in Tianjin',
#   'China',
#   'Tianhe-1A',
#   ' - NUDT YH MPP, Xeon X5670 6C 2.93 GHz, NVIDIA 2050\n                    ',
#   'NUDT',
#   '186,368',
#   '2,566.0',
#   '4,701.0',
#   '4,040'],
#  ['68',
#   'China Meteorological Administration',
#   'China',
#   'PAI-BSystem',
#   ' - Sugon TC4600LP/W740I, Xeon Gold 6142 16C 2.6GHz, Infiniband EDR, NVIDIA Tesla P100\n                    ',
#   'Sugon',
#   '50,816',
#   '2,547.0',
#   '4,229.8',
#   '710'],
#  ['69',
#   'DOE/SC/Pacific Northwest National Laboratory',
#   'United States',
#   'cascade',
#   ' - Atipa Visione IF442 Blade Server, Xeon E5-2670 8C 2.600GHz, Infiniband FDR, Intel Xeon Phi 5110P\n                    ',
#   'Atipa Technology',
#   '194,616',
#   '2,539.1',
#   '3,388.0',
#   '1,384'],
#  ['70',
#   "Grand Equipement National de Calcul Intensif - Centre Informatique National de l'Enseignement Suprieur (GENCI-CINES)",
#   'France',
#   'occigen2',
#   ' - bullx DLC 720, Xeon E5-2690v4 14C 2.6GHz, Infiniband FDR\n                    ',
#   'Bull, Atos Group',
#   '85,824',
#   '2,494.7',
#   '3,570.3',
#   '1,430'],
#  ['71',
#   'Army Research Laboratory DoD Supercomputing Resource Center (ARL DSRC)',
#   'United States',
#   'Excalibur',
#   ' - Cray XC40, Xeon E5-2698v3 16C 2.3GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '100,064',
#   '2,485.0',
#   '3,682.4',
#   '1,466'],
#  ['72',
#   'Moscow State University - Research Computing Center',
#   'Russia',
#   'Lomonosov 2',
#   ' - T-Platform A-Class Cluster, Xeon E5-2697v3 14C 2.6GHz,Intel Xeon Gold 6126, Infiniband FDR, Nvidia K40m/P-100\n                    ',
#   'T-Platforms',
#   '64,384',
#   '2,478.0',
#   '4,946.8'],
#  ['73',
#   'US Army Research Laboratory (ARL)',
#   'United States',
#   'Centennial',
#   ' - SGI ICE XA, Xeon E5-2698v4 20C 2.2GHz, Infiniband EDR\n                    ',
#   'HPE',
#   '73,920',
#   '2,443.7',
#   '2,602.0',
#   '835'],
#  ['74',
#   'China Meteorological Administration',
#   'China',
#   'PAI-ASystem',
#   ' - Sugon TC4600, Xeon Gold 6142 16C 2.6GHz, Infiniband EDR\n                    ',
#   'Sugon',
#   '48,128',
#   '2,435.0',
#   '4,004.2',
#   '740'],
#  ['75',
#   'Korea Meteorological Administration',
#   'Korea, South',
#   'Miri',
#   ' - Cray XC40, Xeon E5-2690v3 12C 2.6GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '69,600',
#   '2,395.7',
#   '2,895.4',
#   '1,359'],
#  ['76',
#   'Korea Meteorological Administration',
#   'Korea, South',
#   'Nuri',
#   ' - Cray XC40, Xeon E5-2690v3 12C 2.6GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '69,600',
#   '2,395.7',
#   '2,895.4',
#   '1,359'],
#  ['77',
#   'National Institute for Fusion Science (NIFS)',
#   'Japan',
#   'Plasma Simulator',
#   ' - Fujitsu PRIMEHPC FX100, SPARC64 XIfx  32C 1.98GHz, Tofu interconnect 2\n                    ',
#   'Fujitsu',
#   '82,944',
#   '2,376.0',
#   '2,621.0',
#   '1,244'],
#  ['78',
#   'Saudi Aramco',
#   'Saudi Arabia',
#   'Makman-3',
#   ' - PowerEdge R440/C6320p, Intel Xeon Phi 7250/Xeon Gold 6130 16C 2.1GHz, Intel Omni-Path\n                    ',
#   'Dell EMC',
#   '53,300',
#   '2,322.5',
#   '3,581.8',
#   '608'],
#  ['79',
#   'Internet Service P',
#   'China',
#   'Inspur TS10000, Xeon Gold 6130 16C 2.1GHz, NVIDIA Tesla V100, 25G Ethernet\n                    ',
#   'Inspur',
#   '55,104',
#   '2,287.0',
#   '4,890.0'],
#  ['80',
#   'Saudi Aramco',
#   'Saudi Arabia',
#   'Makman-2',
#   ' - Dell PowerEdge R630, Xeon E5-2680v3 12C 2.5GHz, Infiniband QDR\n                    ',
#   'Dell EMC',
#   '76,032',
#   '2,249.7',
#   '3,041.3',
#   '1,134'],
#  ['81',
#   'Meteo France',
#   'France',
#   'Prolix2',
#   ' - bullx DLC 720, Xeon E5-2698v4 20C 2.2GHz, Infiniband FDR\n                    ',
#   'Bull, Atos Group',
#   '72,000',
#   '2,168.0',
#   '2,534.4',
#   '830'],
#  ['82',
#   'Meteo France',
#   'France',
#   'Beaufix2',
#   ' - bullx DLC 720, Xeon E5-2698v4 20C 2.2GHz, Infiniband FDR\n                    ',
#   'Bull, Atos Group',
#   '73,440',
#   '2,157.4',
#   '2,585.1',
#   '830'],
#  ['83',
#   'National Astronomical Observatory of Japan',
#   'Japan',
#   'ATERUI II ',
#   ' - Cray XC50, Xeon Gold 6148 20C 2.4GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '40,000',
#   '2,090.0',
#   '3,072.0',
#   '496'],
#  ['84',
#   'LvLiang Cloud Computing Center',
#   'China',
#   'Tianhe-2 LvLiang Solution',
#   ' - Tianhe-2 LvLiang, Intel Xeon E5-2692v2 12C 2.2GHz, TH Express-2, Intel Xeon Phi 31S1P\n                    ',
#   'NUDT',
#   '174,720',
#   '2,071.4',
#   '3,074.5',
#   '997'],
#  ['85',
#   'Navy DSRC',
#   'United States',
#   'Gaffney',
#   ' - HPE SGI 8600, Xeon Platinum 8168 24C 2.7GHz, Intel Omni-Path\n                    ',
#   'HPE',
#   '34,560',
#   '2,002.0',
#   '2,986.0'],
#  ['86',
#   'Navy DSRC',
#   'United States',
#   'Koehr',
#   ' - HPE SGI 8600, Xeon Platinum 8168 24C 2.7GHz, Intel Omni-Path\n                    ',
#   'HPE',
#   '34,560',
#   '2,002.0',
#   '2,986.0'],
#  ['87',
#   'Universitaet Mainz',
#   'Germany',
#   'Mogon II',
#   ' - NEC Cluster, Xeon Gold 6130 16C 2.1GHz, MEGWARE MiriQuid Xeon E5-2630v4, Intel Omni-Path\n                    ',
#   'NEC/MEGWARE',
#   '49,432',
#   '1,967.8',
#   '2,800.9',
#   '657'],
#  ['88',
#   'National Institutes of Health (NIH)',
#   'United States',
#   'Biowulf',
#   ' - Apollo 2000 Gen 8/9, Xeon E5-2680v4/E5-2695v3 14C 2.4GHz, Infiniband FDR\n                    ',
#   'HPE',
#   '66,304',
#   '1,966.1',
#   '2,491.4'],
#  ['89',
#   'Japan Atomic Energy Agency (JAEA)',
#   'Japan',
#   'SGI ICE X, Xeon E5-2680v3 12C 2.5GHz, Infiniband FDR\n                    ',
#   'HPE',
#   '60,240',
#   '1,929.4',
#   '2,409.6',
#   '3,012'],
#  ['90',
#   "Commissariat a l'Energie Atomique (CEA)",
#   'France',
#   'Tera-1000-1',
#   ' - bullx DLC 720, Xeon E5-2698v3 16C 2.3GHz, Infiniband FDR\n                    ',
#   'Bull, Atos Group',
#   '70,272',
#   '1,871.0',
#   '2,586.0',
#   '1,042'],
#  ['91',
#   'Science and Technology Facilities Council',
#   'United Kingdom',
#   'scafellpike',
#   ' - Bull Sequana X1000, Intel Xeon Phi 7210 64C 1.3GHz/Xeon Gold 6142, Mellanox EDR\n                    ',
#   'Bull, Atos Group',
#   '80,640',
#   '1,829.9',
#   '4,329.7',
#   '529'],
#  ['92',
#   'KTH - Royal Institute of Technology',
#   'Sweden',
#   'Beskow',
#   ' - Cray XC40, Xeon E5-2695v4/E5-2698v3 16C 2.3GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '67,456',
#   '1,802.5',
#   '2,438.1',
#   '842'],
#  ['93',
#   'Institute for Molecular Science',
#   'Japan',
#   'Molecular Simulator',
#   ' - NEC LX Cluster, Xeon Gold 6148/6154, Intel Omni-Path\n                    ',
#   'NEC',
#   '38,552',
#   '1,785.6',
#   '3,072.8',
#   '544'],
#  ['94',
#   'BASF',
#   'Germany',
#   'QURIOSITY',
#   ' - Apollo XL230k, Xeon Gold 6148 20C 2.4GHz, Intel Omni-Path\n                    ',
#   'HPE',
#   '35,280',
#   '1,750.2',
#   '2,709.5'],
#  ['95',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212H5, Xeon Platinum 8163 24C 2.5GHz, 10G Ethernet\n                    ',
#   'Inspur',
#   '38,400',
#   '1,729.0',
#   '3,072.0'],
#  ['96',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212H5, Xeon Platinum 8163 24C 2.5GHz, 10G Ethernet\n                    ',
#   'Inspur',
#   '38,400',
#   '1,729.0',
#   '3,072.0'],
#  ['97',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212H5, Xeon Platinum 8163 24C 2.5GHz, 10G Ethernet\n                    ',
#   'Inspur',
#   '38,400',
#   '1,729.0',
#   '3,072.0'],
#  ['98',
#   'CINECA',
#   'Italy',
#   'Marconi Intel Xeon',
#   ' - Lenovo NeXtScale nx360M5, Xeon E5-2697v4 18C 2.3GHz, Omni-Path\n                    ',
#   'Lenovo',
#   '54,432',
#   '1,723.9',
#   '2,003.1',
#   '1,361'],
#  ['99',
#   'Internet Service A',
#   'China',
#   'Inspur TS10000, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet, NVIDIA Tesla P100\n                    ',
#   'Inspur',
#   '39,680',
#   '1,714.0',
#   '3,149.6'],
#  ['100',
#   'Government',
#   'United States',
#   'SwiftLucy',
#   ' - Cluster Platform 3000 BL460c Gen9, Xeon E5-2680v3 12C 2.5GHz, Infiniband FDR\n                    ',
#   'HPE',
#   '57,600',
#   '1,703.3',
#   '2,304.0',
#   '2,880'],
#  [],
#  ['101',
#   'University of Cambridge',
#   'United Kingdom',
#   'Peta4',
#   ' - Dell C6420, Xeon Gold 6142 16C 2.6GHz, Intel Omni-Path\n                    ',
#   'Dell EMC',
#   '46,464',
#   '1,696.6',
#   '2,875.0',
#   '480'],
#  ['102',
#   'National Computational Infrastructure National Facility (NCI-NF)',
#   'Australia',
#   'Raijin',
#   ' - Hybrid Cluster PRIMERGY/x3550 M5/PowerEdge/Rackable/Rackable, Xeon , Infiniband EDR, NVIDIA Tesla P100, Xeon Phi\n                    ',
#   'Fujitsu / Lenovo / Xenon',
#   '87,224',
#   '1,676.2',
#   '3,801.4'],
#  ['103',
#   'Cyfronet',
#   'Poland',
#   'Prometheus',
#   ' - HP Apollo 8000, Xeon E5-2680v3 12C 2.5GHz, Infiniband FDR, NVIDIA Tesla K40\n                    ',
#   'HPE',
#   '55,728',
#   '1,670.1',
#   '2,348.6',
#   '808'],
#  ['104',
#   'DOE/SC/LBNL/NERSC',
#   'United States',
#   'Edison',
#   ' - Cray XC30, Intel Xeon E5-2695v2 12C 2.4GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '133,824',
#   '1,654.7',
#   '2,569.4',
#   '3,747'],
#  ['105',
#   'Cloud Provider',
#   'Australia',
#   'Software Company (M) AA1',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['106',
#   'Hosting Services',
#   'United States',
#   'Software Company (M) A15',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['107',
#   'Hosting Services',
#   'United States',
#   'Software Company (M) A11',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['108',
#   'Hosting Services',
#   'United States',
#   'Software Company (M) A8',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['109',
#   'Hosting Services',
#   'United States',
#   'Software Company (M) A4',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['110',
#   'Hosting Services',
#   'United States',
#   'Software Company (M) A12',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['111',
#   'Hosting Services',
#   'United States',
#   'Software Company (M) A1',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['112',
#   'Hosting Services',
#   'United States',
#   'Software Company (M) A16',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['113',
#   'Hosting Services',
#   'United States',
#   'Software Company (M) A13',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['114',
#   'Hosting Services',
#   'United States',
#   'Software Company (M) A9',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['115',
#   'Hosting Services',
#   'United States',
#   'Software Company (M) A6',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['116',
#   'Hosting Services',
#   'United States',
#   'Software Company (M) A2',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['117',
#   'Hosting Services',
#   'United States',
#   'Software Company (M) A14',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['118',
#   'Hosting Services',
#   'United States',
#   'Software Company (M) A10',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['119',
#   'Hosting Services',
#   'United States',
#   'Software Company (M) A7',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['120',
#   'Hosting Services',
#   'United States',
#   'Software Company (M) A3',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['121',
#   'Hosting Services',
#   'United States',
#   'Software Company (M) A5',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['122',
#   'Software Company (M)',
#   'Ireland',
#   'IA1',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['123',
#   'Software Company (M)',
#   'Netherlands',
#   'NA4',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['124',
#   'Software Company (M)',
#   'Netherlands',
#   'NA1',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['125',
#   'Software Company (M)',
#   'Ireland',
#   'IA2',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['126',
#   'Software Company (M)',
#   'Netherlands',
#   'NA5',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['127',
#   'Software Company (M)',
#   'Netherlands',
#   'NA2',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['128',
#   'Software Company (M)',
#   'Ireland',
#   'IA3',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['129',
#   'Software Company (M)',
#   'Netherlands',
#   'NA3',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['130',
#   'Software Company (M)',
#   'Ireland',
#   'IA4',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '57,600',
#   '1,649.1',
#   '2,119.7'],
#  ['131',
#   'EPSRC/University of Edinburgh',
#   'United Kingdom',
#   'ARCHER',
#   ' - Cray XC30, Intel Xeon E5 v2 12C 2.700GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '118,080',
#   '1,642.5',
#   '2,550.5',
#   '3,306'],
#  ['132',
#   'NOAA',
#   'United States',
#   'Luna',
#   ' - Cray XC40, Xeon E5-2690v3 12C 2.6GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '48,960',
#   '1,635.0',
#   '2,036.7',
#   '956'],
#  ['133',
#   'NOAA',
#   'United States',
#   'Surge',
#   ' - Cray XC40, Xeon E5-2690v3 12C 2.6GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '48,960',
#   '1,635.0',
#   '2,036.7',
#   '956'],
#  ['134',
#   'Information Systems Division, RIKEN',
#   'Japan',
#   'HOKUSAI BigWaterfall\t',
#   ' - PRIMERGY CX2550 M4, Xeon Gold 6148 20C 2.4GHz, Infiniband EDR\n                    ',
#   'Fujitsu',
#   '33,600',
#   '1,601.0',
#   '2,580.5'],
#  ['135',
#   'IBM Development Engineering',
#   'United States',
#   'Power 775, POWER7 8C 3.836GHz, Custom Interconnect\n                    ',
#   'IBM',
#   '62,944',
#   '1,587.0',
#   '1,931.6',
#   '3,576'],
#  ['136',
#   'Los Alamos National Laboratory',
#   'United States',
#   'LANL CTS-1 Grizzly',
#   ' - Tundra Extreme Scale, Xeon E5-2695v4 18C 2.1GHz, Intel Omni-Path\n                    ',
#   'Penguin Computing, Inc.',
#   '53,352',
#   '1,524.7',
#   '1,792.6',
#   '603'],
#  ['137',
#   'Internet Service A',
#   'China',
#   'Inspur TS10000, Xeon Silver 4114 10C 2.2GHz, NVIDIA Tesla V100, Infiniband FDR\n                    ',
#   'Inspur',
#   '33,000',
#   '1,471.0',
#   '3,000.0'],
#  ['138',
#   'Intel',
#   'United States',
#   'Endeavor',
#   ' - Intel Cluster, Intel Xeon Gold 6148/Xeon Phi 7250F 68C 1.4GHz, Intel Omni-Path\n                    ',
#   'Intel',
#   '45,680',
#   '1,463.0',
#   '2,507.3',
#   '431'],
#  ['139',
#   'IT4Innovations National Supercomputing Center, VSB-Technical University of Ostrava',
#   'Czech Republic',
#   'Salomon',
#   ' - SGI ICE X, Xeon E5-2680v3 12C 2.5GHz, Infiniband FDR, Intel Xeon Phi 7120P\n                    ',
#   'HPE',
#   '76,896',
#   '1,457.7',
#   '2,011.6',
#   '4,806'],
#  ['140',
#   'Science and Technology Facilities Council - Daresbury Laboratory',
#   'United Kingdom',
#   'Blue Joule',
#   ' - BlueGene/Q, Power BQC 16C 1.60GHz, Custom\n                    ',
#   'IBM',
#   '131,072',
#   '1,431.1',
#   '1,677.7',
#   '657'],
#  ['141',
#   'Air Force Research Laboratory',
#   'United States',
#   'Spirit',
#   ' - SGI ICE X, Xeon E5-2670 8C 2.600GHz, Infiniband FDR\n                    ',
#   'HPE',
#   '73,584',
#   '1,415.5',
#   '1,530.5',
#   '1,606'],
#  ['142',
#   'Swiss National Supercomputing Centre (CSCS)',
#   'Switzerland',
#   'Piz Daint Multicore',
#   ' - Cray XC40, Xeon E5-2695v4 18C 2.1GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '44,928',
#   '1,410.7',
#   '1,509.6',
#   '519'],
#  ['143',
#   'NTT Communications Tokyo No.4 Data Center',
#   'Japan',
#   'MN-1',
#   ' - SuperServer 4028GR-TR2, Xeon E5-2667v4 8C 3.2GHz, Infiniband FDR, NVIDIA Tesla P100\n                    ',
#   'NTT Communications / NTT PC Communications',
#   '59,392',
#   '1,391.0',
#   '4,917.7'],
#  ['144',
#   'Atos',
#   'France',
#   'Sid',
#   ' - bullx DLC 720, Xeon E5-2695v4 18C 2.1GHz, Infiniband FDR\n                    ',
#   'Bull, Atos Group',
#   '49,896',
#   '1,363.5',
#   '1,676.5',
#   '543'],
#  ['145',
#   'CEA/TGCC-GENCI',
#   'France',
#   'Curie thin nodes',
#   ' - Bullx B510, Xeon E5-2680 8C 2.700GHz, Infiniband QDR\n                    ',
#   'Bull, Atos Group',
#   '77,184',
#   '1,359.0',
#   '1,667.2',
#   '2,132'],
#  ['146',
#   'Internet Service A',
#   'China',
#   'Inspur NF5280M, Xeon E5-2682v4 16C 2.5GHz, NVIDIA Tesla P100, 25G Ethernet\n                    ',
#   'Inspur',
#   '31,680',
#   '1,352.0',
#   '2,332.0'],
#  ['147',
#   'Simon Fraser University/Compute Canada',
#   'Canada',
#   'Cedar',
#   ' - Dell C4130/Dell C6320, Xeon E5-2650v4/E5-2683-v4, Intel Omni-Path, NVIDIA Tesla P100\n                    ',
#   'Dell EMC',
#   '59,776',
#   '1,337.0',
#   '3,710.5',
#   '167'],
#  ['148',
#   'National Center for High Performance Computing',
#   'Taiwan',
#   'Taiwania',
#   ' - PRIMERGY CX2550 M4/CX2560 M4/CX2570 M4, Xeon Gold 6148 20C 2.4GHz, Intel Omni-Path\n                    ',
#   'Fujitsu',
#   '27,200',
#   '1,325.2',
#   '2,089.0',
#   '332'],
#  ['149',
#   'Service Provider T',
#   'China',
#   'Internet Company T EE1',
#   ' - Lenovo HR650x, Xeon Gold 6133 20C 2.5GHz, 25G Ethernet\n                    ',
#   'Lenovo',
#   '30,000',
#   '1,319.5',
#   '2,400.0'],
#  ['150',
#   'Service Provider T',
#   'China',
#   'Internet Company T EE2',
#   ' - Lenovo HR650x, Xeon Gold 6133 20C 2.5GHz, 25G Ethernet\n                    ',
#   'Lenovo',
#   '30,000',
#   '1,319.5',
#   '2,400.0'],
#  ['151',
#   'CEA/TGCC-GENCI',
#   'France',
#   'JOLIOT-CURIE KNL',
#   ' - Bull Sequana X1000, Intel Xeon Phi 7250 68C 1.4GHz, Bull BXI 1.2\n                    ',
#   'Bull, Atos Group',
#   '56,304',
#   '1,311.3',
#   '2,339.6',
#   '326'],
#  ['152',
#   'Government',
#   'China',
#   'AIGIS',
#   ' - Sugon Cluster W780I, Xeon E5-2630v4 10C 2.2GHz, NVIDIA Tesla P100, Infiniband FDR\n                    ',
#   'Sugon',
#   '24,400',
#   '1,307.0',
#   '1,950.4',
#   '300'],
#  ['153',
#   "Commissariat a l'Energie Atomique (CEA)/CCRT",
#   'France',
#   'Cobalt',
#   ' - bullx DLC 720, Xeon E5-2680v4 14C 2.4GHz, Infiniband EDR\n                    ',
#   'Bull, Atos Group',
#   '38,528',
#   '1,299.5',
#   '1,479.5',
#   '539'],
#  ['154',
#   'Navy DSRC',
#   'United States',
#   'Gordon',
#   ' - Cray XC40, Xeon E5-2698v3 16C 2.3GHz, Aries interconnect , Intel Xeon Phi 5120D\n                    ',
#   'Cray Inc.',
#   '61,256',
#   '1,285.6',
#   '2,049.6',
#   '2,324'],
#  ['155',
#   'Navy DSRC',
#   'United States',
#   'Conrad',
#   ' - Cray XC40, Xeon E5-2698v3 16C 2.3GHz, Aries interconnect , Intel Xeon Phi 5120D\n                    ',
#   'Cray Inc.',
#   '61,256',
#   '1,285.6',
#   '2,049.6',
#   '2,324'],
#  ['156',
#   'Max-Planck-Gesellschaft MPI/IPP',
#   'Germany',
#   'iDataPlex DX360M4, Intel Xeon E5-2680v2  10C 2.800GHz, Infiniband FDR\n                    ',
#   'Lenovo/IBM',
#   '65,320',
#   '1,283.3',
#   '1,463.2',
#   '1,260'],
#  ['157',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212M4, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Inspur',
#   '66,560',
#   '1,276.0',
#   '2,662.4'],
#  ['158',
#   'National Supercomputing Centre in Shenzhen (NSCS)',
#   'China',
#   'Nebulae',
#   ' - Dawning TC3600 Blade System, Xeon X5650 6C 2.66GHz, Infiniband QDR, NVIDIA 2050\n                    ',
#   'Sugon',
#   '120,640',
#   '1,271.0',
#   '2,984.3',
#   '2,580'],
#  ['159',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212M4, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Inspur',
#   '65,280',
#   '1,271.0',
#   '2,611.2'],
#  ['160',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212M4, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Inspur',
#   '64,000',
#   '1,269.0',
#   '2,560.0'],
#  ['161',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212M4, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Inspur',
#   '64,000',
#   '1,269.0',
#   '2,560.0'],
#  ['162',
#   'National Center for Atmospheric Research (NCAR)',
#   'United States',
#   'Yellowstone',
#   ' - iDataPlex DX360M4, Xeon E5-2670 8C 2.600GHz, Infiniband FDR\n                    ',
#   'IBM',
#   '72,288',
#   '1,257.6',
#   '1,503.6',
#   '1,437'],
#  ['163',
#   'CSC (Center for Scientific Computing)',
#   'Finland',
#   'Sisu',
#   ' - Cray XC40, Xeon E5-2690v3 12C 2.6GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '40,608',
#   '1,250.0',
#   '1,689.3',
#   '680'],
#  ['164',
#   'Internet Service (B)',
#   'China',
#   'CTRtraning',
#   ' - Sugon I620, Xeon E5-2650v4 12C 2.2GHz, 10G Ethernet\n                    ',
#   'Sugon',
#   '72,000',
#   '1,242.0',
#   '2,534.4',
#   '900'],
#  ['165',
#   'Computer Network Information Center, Chinese Academy of Science',
#   'China',
#   'Era-AI',
#   ' - Sugon Cluster W780I, Xeon E5-2650v4 12C 2.2GHz, NVIDIA Tesla P100, Infiniband FDR\n                    ',
#   'Sugon',
#   '22,656',
#   '1,238.0',
#   '1,845.4',
#   '144'],
#  ['166',
#   'SharcNet',
#   'Canada',
#   'Graham',
#   ' - Huawei X6800 V3, Xeon E5-2683 v4  16C 2.1GHz, Infiniband EDR/FDR, NVIDIA Tesla P100\n                    ',
#   'Huawei Technologies Co., Ltd.',
#   '51,200',
#   '1,228.0',
#   '2,641.4',
#   '546'],
#  ['167',
#   'Atos',
#   'France',
#   'Diego',
#   ' - bullx DLC 720, Xeon E5-2698v4 20C 2.2GHz, Infiniband FDR\n                    ',
#   'Bull, Atos Group',
#   '46,800',
#   '1,225.3',
#   '1,647.4',
#   '472'],
#  ['168',
#   'Sandia National Laboratories',
#   'United States',
#   'SNL/NNSA CTS-1 Serrano',
#   ' - Tundra Extreme Scale, Xeon E5-2695v4 18C 2.1GHz, Intel Omni-Path\n                    ',
#   'Penguin Computing, Inc.',
#   '40,392',
#   '1,223.7',
#   '1,357.2',
#   '480'],
#  ['169',
#   'Sandia National Laboratories',
#   'United States',
#   'SNL/NNSA CTS-1 Cayenne',
#   ' - Tundra Extreme Scale, Xeon E5-2695v4 18C 2.1GHz, Intel Omni-Path\n                    ',
#   'Penguin Computing, Inc.',
#   '40,392',
#   '1,223.7',
#   '1,357.2',
#   '480'],
#  ['170',
#   'Deutscher Wetterdienst',
#   'Germany',
#   'Cray XC40, E5-2680v3 12C 2.5Ghz/Xeon E5-2695v4 18C 2.1GHz, Aries interconnect \n                    ',
#   'Cray Inc.',
#   '41,472',
#   '1,214.2',
#   '1,459.8',
#   '528'],
#  ['171',
#   'Center for Advanced Intelligence Project, RIKEN',
#   'Japan',
#   'RAIDEN GPU subsystem',
#   ' - NVIDIA DGX-1 Volta36, Xeon E5-2698v4 20C 2.2GHz, Infiniband EDR, NVIDIA Tesla V100\n                    ',
#   'Fujitsu',
#   '35,360',
#   '1,213.0',
#   '3,244.8',
#   '107'],
#  ['172',
#   'Main Computer Center of Roshydromet',
#   'Russia',
#   'Cray XC40, Xeon E5-2697v4 18C 2.3GHz, Aries interconnect \n                    ',
#   'Cray Inc./T-Platforms',
#   '35,136',
#   '1,200.3',
#   '1,293.0'],
#  ['173',
#   'University of Cambridge',
#   'United Kingdom',
#   'Wilkes-2',
#   ' - Dell C4130, Xeon E5-2650v4 12C 2.2GHz, Infiniband EDR, NVIDIA Tesla P100\n                    ',
#   'Dell EMC',
#   '21,240',
#   '1,193.0',
#   '1,751.6',
#   '114'],
#  ['174',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212H5, Xeon E5-2682v4 16C 2.5GHz, NVIDIA Tesla P100, 25G Ethernet\n                    ',
#   'Inspur',
#   '28,800',
#   '1,188.0',
#   '2,120.0'],
#  ['175',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212H5, Xeon E5-2682v4 16C 2.5GHz, NVIDIA Tesla P100, 25G Ethernet\n                    ',
#   'Inspur',
#   '28,800',
#   '1,188.0',
#   '2,120.0'],
#  ['176',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212H5, Xeon E5-2682v4 16C 2.5GHz, NVIDIA Tesla P100, 25G Ethernet\n                    ',
#   'Inspur',
#   '24,960',
#   '1,182.0',
#   '2,204.8'],
#  ['177',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212H5, Xeon E5-2682v4 16C 2.5GHz, NVIDIA Tesla P100, 25G Ethernet\n                    ',
#   'Inspur',
#   '24,960',
#   '1,182.0',
#   '2,204.8'],
#  ['178',
#   'Manufacturing Company',
#   'United States',
#   'Apollo 6000 XL230k, Xeon Gold 6142 16C 2.6GHz, Infiniband EDR\n                    ',
#   'HPE',
#   '23,808',
#   '1,181.1',
#   '1,980.8'],
#  ['179',
#   'Lawrence Livermore National Laboratory',
#   'United States',
#   'LLNL/NNSA CTS-1 Nel',
#   ' - Tundra Extreme Scale, Xeon E5-2695v4 18C 2.1GHz, Intel Omni-Path\n                    ',
#   'Penguin Computing, Inc.',
#   '39,744',
#   '1,179.6',
#   '1,335.4',
#   '485'],
#  ['180',
#   'University of Tokyo/Institute for Solid State Physics',
#   'Japan',
#   'Sekirei',
#   ' - SGI ICE XA, Xeon E5-2680v3 12C 2.5GHz, Infiniband FDR\n                    ',
#   'HPE',
#   '38,016',
#   '1,178.3',
#   '1,520.6',
#   '581'],
#  ['181',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212H5, Xeon E5-2682v4 16C 2.5GHz, NVIDIA Tesla P100, 25G Ethernet\n                    ',
#   'Inspur',
#   '12,800',
#   '1,171.0',
#   '2,120.0'],
#  ['182',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212H5, Xeon E5-2682v4 16C 2.5GHz, NVIDIA Tesla P100, 25G Ethernet\n                    ',
#   'Inspur',
#   '12,800',
#   '1,171.0',
#   '2,120.0'],
#  ['183',
#   'ERDC DSRC',
#   'United States',
#   'Garnet',
#   ' - Cray XE6, Opteron 16C 2.500GHz, Cray Gemini interconnect\n                    ',
#   'Cray Inc.',
#   '150,528',
#   '1,167.0',
#   '1,505.3',
#   '5,569'],
#  ['184',
#   'Internet Company',
#   'China',
#   'Inspur TS10000, Xeon Gold 6130 16C 2.1GHz, NVIDIA Tesla V100, Infiniband EDR\n                    ',
#   'Inspur',
#   '26,880',
#   '1,161.0',
#   '2,400.0'],
#  ['185',
#   'Service Provider T',
#   'China',
#   'Internet Company T CC1',
#   ' - Lenovo RD450, Xeon E5-2670v3 12C 2.3GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '64,320',
#   '1,156.5',
#   '2,367.0'],
#  ['186',
#   'Internet Service A',
#   'China',
#   'Inspur NF5280M, Xeon E5-2682v4 16C 2.5GHz, NVIDIA Tesla P100, 25G Ethernet\n                    ',
#   'Inspur',
#   '28,800',
#   '1,152.0',
#   '2,544.0'],
#  ['187',
#   'Service Provider T',
#   'China',
#   'Lenovo RD450, Xeon E5-2670v3 12C 2.3GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '78,000',
#   '1,149.6',
#   '2,870.4',
#   '2,438'],
#  ['188',
#   'Service Provider T',
#   'China',
#   'Internet Company T DD1',
#   ' - Lenovo RD350, Xeon E5-2620v4 8C 2.1GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '75,776',
#   '1,145.2',
#   '2,546.1'],
#  ['189',
#   'Los Alamos National Laboratory',
#   'United States',
#   'LANL/NNSA CTS-1 Ice',
#   ' - Tundra Extreme Scale, Xeon E5-2695v4 18C 2.1GHz, Intel Omni-Path\n                    ',
#   'Penguin Computing, Inc.',
#   '39,672',
#   '1,144.8',
#   '1,333.0',
#   '486'],
#  ['190',
#   'Los Alamos National Laboratory',
#   'United States',
#   'LANL/NNSA CTS-1 Fire',
#   ' - Tundra Extreme Scale, Xeon E5-2695v4 18C 2.1GHz, Intel Omni-Path\n                    ',
#   'Penguin Computing, Inc.',
#   '39,672',
#   '1,144.8',
#   '1,333.0',
#   '486'],
#  ['191',
#   'Sandia National Laboratories',
#   'United States',
#   'SNL/NNSA CTS-1 Eclipse',
#   ' - Tundra Extreme Scale, Xeon E5-2695v4 18C 2.1GHz, Intel Omni-Path\n                    ',
#   'Penguin Computing, Inc.',
#   '41,256',
#   '1,142.4',
#   '1,156.8',
#   '480'],
#  ['192',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212M4, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Inspur',
#   '59,520',
#   '1,128.0',
#   '2,380.8'],
#  ['193',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212M4, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Inspur',
#   '59,520',
#   '1,128.0',
#   '2,380.8'],
#  ['194',
#   'Internet Service A',
#   'China',
#   'Inspur NF5280M, Xeon E5-2682v4 16C 2.5GHz, NVIDIA Tesla P100, 25G Ethernet\n                    ',
#   'Inspur',
#   '28,800',
#   '1,128.0',
#   '2,120.0'],
#  ['195',
#   'Internet Service A',
#   'China',
#   'Inspur NF5280M, Xeon E5-2682v4 16C 2.5GHz, NVIDIA Tesla P100, 10G Ethernet\n                    ',
#   'Inspur',
#   '28,800',
#   '1,128.0',
#   '2,120.0'],
#  ['196',
#   'Internet Service A',
#   'China',
#   'Inspur NF5280M, Xeon E5-2682v4 16C 2.5GHz, NVIDIA Tesla P100, 25G Ethernet\n                    ',
#   'Inspur',
#   '28,800',
#   '1,128.0',
#   '2,120.0'],
#  ['197',
#   'Service Provider T',
#   'China',
#   'Internet Company T BB1',
#   ' - Lenovo RD450, Xeon E5-2670v3 12C 2.3GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '62,400',
#   '1,127.5',
#   '2,296.3'],
#  ['198',
#   'Internet Service (B)',
#   'China',
#   'data-ML',
#   ' - Sugon I620, Xeon E5-2650v4 12C 2.2GHz, 10G Ethernet\n                    ',
#   'Sugon',
#   '64,800',
#   '1,124.0',
#   '2,281.0',
#   '1,620'],
#  ['199',
#   'Cloud Provider',
#   'Brazil',
#   'BC1',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '38,400',
#   '1,123.2',
#   '1,413.1'],
#  ['200',
#   'Cloud Provider',
#   'Australia',
#   'AC1',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '38,400',
#   '1,123.2',
#   '1,413.1'],
#  [],
#  ['201',
#   'Software Company',
#   'Korea, South',
#   'KC1',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '38,400',
#   '1,123.2',
#   '1,413.1'],
#  ['202',
#   'Software Company (M)',
#   'United Kingdom',
#   'UKC3',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '38,400',
#   '1,123.2',
#   '1,413.1'],
#  ['203',
#   'Software Company (M)',
#   'United Kingdom',
#   'UKC1',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '38,400',
#   '1,123.2',
#   '1,413.1'],
#  ['204',
#   'Software Company (M)',
#   'United Kingdom',
#   'UKC4',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '38,400',
#   '1,123.2',
#   '1,413.1'],
#  ['205',
#   'Software Company (M)',
#   'United Kingdom',
#   'UKC2',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '38,400',
#   '1,123.2',
#   '1,413.1'],
#  ['206',
#   'Software Company (M)',
#   'India',
#   'InC1',
#   ' - Lenovo C1040, Xeon E5-2673v4 20C 2.3GHz, 40G Ethernet\n                    ',
#   'Lenovo',
#   '38,400',
#   '1,123.2',
#   '1,413.1'],
#  ['207',
#   'NOAA',
#   'United States',
#   'Mars',
#   ' - PowerEdge C6320, Xeon E5-2690v4 14C 2.6GHz, Infiniband EDR\n                    ',
#   'Dell EMC / IBM-GBS',
#   '33,600',
#   '1,121.1',
#   '1,397.8'],
#  ['208',
#   'NOAA',
#   'United States',
#   'Venus',
#   ' - PowerEdge C6320, Xeon E5-2690v4 14C 2.6GHz, Infiniband EDR\n                    ',
#   'Dell EMC / IBM-GBS',
#   '33,600',
#   '1,121.1',
#   '1,397.8'],
#  ['209',
#   'Telecom Company',
#   'China',
#   'CT-1',
#   ' - Sugon TC6000, Xeon E5-2630v4 10C 2.2GHz, 10G Ethernet\n                    ',
#   'Sugon',
#   '66,000',
#   '1,121.0',
#   '2,323.2'],
#  ['210',
#   'Internet Company',
#   'China',
#   'PVideo-C',
#   ' - Sugon I620, Xeon E5-2620v4 8C 2.1GHz, 10G Ethernet\n                    ',
#   'Sugon',
#   '67,200',
#   '1,108.0',
#   '2,257.9',
#   '1,050'],
#  ['211',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212M4, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Inspur',
#   '57,600',
#   '1,106.0',
#   '2,304.0'],
#  ['212',
#   'Internet Service A',
#   'China',
#   'Inspur SA5212M4, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Inspur',
#   '57,600',
#   '1,106.0',
#   '2,304.0'],
#  ['213',
#   'Energy Company (DD)',
#   'United States',
#   'Dell C4130, Xeon E5-2630v3 8C 2.4GHz, Infiniband FDR, NVIDIA Tesla K80\n                    ',
#   'Dell EMC',
#   '25,920',
#   '1,106.0',
#   '1,748.4',
#   '3,564'],
#  ['214',
#   'Internet Company',
#   'China',
#   'MLSystem',
#   ' - Sugon I620, Xeon E5-2630v4 10C 2.2GHz, 10G Ethernet\n                    ',
#   'Sugon',
#   '64,000',
#   '1,102.0',
#   '2,252.8',
#   '960'],
#  ['215',
#   'Internet Company A',
#   'China',
# ...
#   'Internet Company T S1',
#   ' - Lenovo RD450, Xeon E5-2630v4 10C 2.2GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '46,000',
#   '793.1',
#   '1,619.2'],
#  ['424',
#   'Max-Planck-Gesellschaft MPI/IPP',
#   'Germany',
#   'DRACO',
#   ' - Lenovo NeXtScale nx360M5, Xeon E5-2698v3 16C 2.3GHz, Infiniband FDR\n                    ',
#   'Lenovo',
#   '28,128',
#   '790.7',
#   '1,035.1'],
#  ['425',
#   'Network Company',
#   'China',
#   'Internet Company N D1',
#   ' - Lenovo RD350, Xeon E5-2630v4 10C 2.2GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '45,600',
#   '788.4',
#   '1,605.1'],
#  ['426',
#   'Internet Company A',
#   'China',
#   'Internet Company A Q1',
#   ' - Lenovo x3650, Xeon E5-2690v4 14C 2.6GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '39,200',
#   '788.2',
#   '1,630.7'],
#  ['427',
#   'Internet Service (B)',
#   'China',
#   'Sugon TC6000, Xeon E5-2630v4 10C 2.2GHz, 10G Ethernet\n                    ',
#   'Sugon',
#   '46,000',
#   '788.2',
#   '1,619.2',
#   '1,076'],
#  ['428',
#   'University (A)',
#   'China',
#   'Huawei X6800 V3, Xeon E5-2683 v4  16C 2.1GHz, Infiniband EDR\n                    ',
#   'Huawei Technologies Co., Ltd.',
#   '28,160',
#   '787.1',
#   '946.2',
#   '358'],
#  ['429',
#   'Software Company (M)',
#   'United States',
#   'Cluster Platform DL360, Xeon E5-2673v3 12C 2.4GHz, 10G Ethernet\n                    ',
#   'HPE',
#   '34,560',
#   '785.3',
#   '1,327.1'],
#  ['430',
#   'Software Company (M)',
#   'Netherlands',
#   'Cluster Platform DL360, Xeon E5-2673v3 12C 2.4GHz, 10G Ethernet\n                    ',
#   'HPE',
#   '34,560',
#   '785.3',
#   '1,327.1'],
#  ['431',
#   'Software Company (M)',
#   'Netherlands',
#   'Cluster Platform DL360, Xeon E5-2673v3 12C 2.4GHz, 10G Ethernet\n                    ',
#   'HPE',
#   '34,560',
#   '785.3',
#   '1,327.1'],
#  ['432',
#   'Software Company (M)',
#   'United States',
#   'Cluster Platform DL360, Xeon E5-2673v3 12C 2.4GHz, 10G Ethernet\n                    ',
#   'HPE',
#   '34,560',
#   '785.3',
#   '1,327.1'],
#  ['433',
#   'Stanford Research Computing Center',
#   'United States',
#   'XStream',
#   ' - Cray CS-Storm, Intel Xeon E5-2680v2  10C 2.8GHz, Infiniband FDR, Nvidia K80\n                    ',
#   'Cray Inc.',
#   '14,820',
#   '781.3',
#   '1,001.7',
#   '190'],
#  ['434',
#   'Internet Service A',
#   'China',
#   'Inspur TS10000, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet, NVIDIA Tesla P100\n                    ',
#   'Inspur',
#   '17,920',
#   '779.2',
#   '1,422.4'],
#  ['435',
#   'Network Company',
#   'China',
#   'Internet Company N D2',
#   ' - Lenovo RD350, Xeon E5-2630v4 10C 2.2GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '45,000',
#   '777.7',
#   '1,584.0'],
#  ['436',
#   'University of Tokyo/Institute for Solid State Physics',
#   'Japan',
#   'Sekirei-ACC',
#   ' - SGI ICE XA, Xeon E5-2680v3 12C 2.5GHz, Infiniband FDR, Nvidia K40\n                    ',
#   'HPE',
#   '15,552',
#   '777.4',
#   '1,100.2',
#   '255'],
#  ['437',
#   'Lawrence Livermore National Laboratory',
#   'United States',
#   'Zin',
#   ' - Xtreme-X GreenBlade GB512X, Xeon E5 (Sandy Bridge - EP) 8C 2.60GHz, Infiniband QDR\n                    ',
#   'Cray Inc.',
#   '46,208',
#   '773.7',
#   '961.1',
#   '924'],
#  ['438',
#   'National Super Computer Center in Hunan',
#   'China',
#   'Tianhe-1A Hunan Solution',
#   ' - NUDT YH MPP, Xeon X5670 6C 2.93 GHz, Proprietary, NVIDIA 2050\n                    ',
#   'NUDT',
#   '53,248',
#   '771.7',
#   '1,342.8',
#   '1,155'],
#  ['439',
#   'Qingdao National Laboratory for Marine Science and Technology',
#   'China',
#   'Inspur TS10000, Xeon E5-2690v3 12C 2.6GHz/Xeon E5-2690v4, Intel Omni-Path\n                    ',
#   'Inspur',
#   '23,920',
#   '771.3',
#   '1,030.2',
#   '162'],
#  ['440',
#   'National Institute for Environmental Studies',
#   'Japan',
#   'Research Computation Facility for GOSAT-2 (RCF2)',
#   ' - SGI Rackable C1104-GP1, Xeon E5-2650v4 12C 2.2GHz, Infiniband EDR, NVIDIA Tesla P100\n                    ',
#   'NSSOL/HPE',
#   '16,320',
#   '770.4',
#   '1,243.8',
#   '79'],
#  ['441',
#   'Research (B)',
#   'China',
#   'Research',
#   ' - Sugon TC6000, Xeon Gold 6132 14C 2.6GHz, Intel Omni-Path\n                    ',
#   'Sugon',
#   '12,880',
#   '769.2',
#   '1,071.6',
#   '184'],
#  ['442',
#   'Karlsruher Institut für Technologie (KIT) ',
#   'Germany',
#   'ForHLR II',
#   ' - Lenovo NeXtScale nx360M5, Xeon E5-2660v3 10C 2.6GHz, Infiniband EDR/FDR\n                    ',
#   'Lenovo',
#   '22,960',
#   '768.3',
#   '955.1',
#   '435'],
#  ['443',
#   'Service Provider T',
#   'China',
#   'Internet Company T T1',
#   ' - Lenovo RD450, Xeon E5-2680v4 14C 2.4GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '40,320',
#   '768.0',
#   '1,548.3'],
#  ['444',
#   'AWE',
#   'United Kingdom',
#   'Spruce B',
#   ' - SGI ICE X, Intel Xeon E5-2680v2  10C 2.8GHz, Infiniband FDR\n                    ',
#   'HPE',
#   '35,640',
#   '767.5',
#   '798.3',
#   '685'],
#  ['445',
#   'Service Provider T',
#   'China',
#   'Internet Company T U1',
#   ' - Lenovo RD450, Xeon E5-2670v3 12C 2.3GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '40,800',
#   '765.6',
#   '1,501.4'],
#  ['446',
#   'Service Provider T',
#   'China',
#   'Internet Company T U2',
#   ' - Lenovo RD450, Xeon E5-2670v3 12C 2.3GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '40,800',
#   '765.6',
#   '1,501.4'],
#  ['447',
#   'Petroleum Company',
#   'China',
#   'Huawei RH2288H V3 Cluster, Xeon E5-2680v4 14C 2.4GHz, Infiniband FDR\n                    ',
#   'Huawei Technologies Co., Ltd.',
#   '26,880',
#   '763.8',
#   '1,032.2',
#   '374'],
#  ['448',
#   'Sandia National Laboratories',
#   'United States',
#   'SNL CTS-1 Dark Ghost',
#   ' - Tundra Extreme Scale, Xeon E5-2695v4 18C 2.1GHz, Intel Omni-Path\n                    ',
#   'Penguin Computing, Inc.',
#   '25,920',
#   '761.8',
#   '870.9',
#   '320'],
#  ['449',
#   'Penguin Computing, Inc.',
#   'United States',
#   'Topaz',
#   ' - Tundra Extreme Scale, Xeon E5-2695v4 18C 2.1GHz, Intel Omni-Path\n                    ',
#   'Penguin Computing, Inc.',
#   '26,496',
#   '759.9',
#   '778.5',
#   '321'],
#  ['450',
#   'Service Provider',
#   'Korea, South',
#   'HP Apollo XL1x0r, Xeon E5-2683 v4  16C 2.1GHz, Infiniband EDR\n                    ',
#   'HPE',
#   '30,720',
#   '759.6',
#   '1,032.2'],
#  ['451',
#   'E-Commerce',
#   'United States',
#   'Cluster Platform DL360, Xeon E5-2660v4 14C 2GHz, 10G Ethernet\n                    ',
#   'HPE',
#   '41,132',
#   '758.6',
#   '1,316.2'],
#  ['452',
#   'Retailer (C)',
#   'United States',
#   'Cluster Platform DL380, Xeon E5-2630v4 10C 2.2GHz, 10G Ethernet\n                    ',
#   'HPE',
#   '36,500',
#   '758.6',
#   '1,284.8'],
#  ['453',
#   'Retailer (C)',
#   'United States',
#   'Cluster Platform DL380, Xeon E5-2630v4 10C 2.2GHz, 10G Ethernet\n                    ',
#   'HPE',
#   '36,500',
#   '758.6',
#   '1,284.8'],
#  ['454',
#   'Service Provider',
#   'Korea, South',
#   'Cluster Platform DL380, Xeon E5-2680v4 14C 2.4GHz, 10G Ethernet\n                    ',
#   'HPE',
#   '32,760',
#   '757.0',
#   '1,258.0'],
#  ['455',
#   'Internet Company A',
#   'China',
#   'Lenovo ThinkServer RD650, Intel Xeon E5-2650v3 10C 2GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '70,000',
#   '756.9',
#   '2,240.0',
#   '2,625'],
#  ['456',
#   'Internet Company A',
#   'China',
#   'Lenovo ThinkServer RD650, Intel Xeon E5-2650v3 10C 2GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '70,000',
#   '756.9',
#   '2,240.0',
#   '2,625'],
#  ['457',
#   'Internet Company A',
#   'China',
#   'Lenovo ThinkServer RD650, Intel Xeon E5-2650v3 10C 2GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '70,000',
#   '756.9',
#   '2,240.0',
#   '2,625'],
#  ['458',
#   'National Research Centre "Kurchatov Institute"',
#   'Russia',
#   'HPC4/HPC5',
#   ' - SuperMicro Twin^2/2U GPU/T-Platforms V205 , Xeon E5-2680v3 12C 2.5GHz, Infiniband FDR, NVIDIA Tesla K80\n                    ',
#   'SuperMicro/Mellanox',
#   '22,700',
#   '755.5',
#   '1,268.4'],
#  ['459',
#   'Software Company (M)',
#   'United States',
#   'Cluster Platform DL380, Xeon E5-2673v3 12C 2.4GHz, 10G Ethernet\n                    ',
#   'HPE',
#   '30,000',
#   '753.5',
#   '1,152.0',
#   '1,000'],
#  ['460',
#   'IT Service Provider',
#   'China',
#   'Sugon TC6000, Xeon E5-2630v4 10C 2.2GHz, 10G Ethernet\n                    ',
#   'Sugon',
#   '44,000',
#   '752.3',
#   '1,548.8',
#   '1,029'],
#  ['461',
#   'Government Research Center',
#   'China',
#   'Sugon TC6000, Xeon E5-2680v3 12C 2.5GHz, 10G Ethernet\n                    ',
#   'Sugon',
#   '38,400',
#   '752.3',
#   '1,536.0',
#   '672'],
#  ['462',
#   'Internet Service (B)',
#   'China',
#   'Inspur TS10000, Xeon E5-2670v3 12C 2.3GHz, 10G Ethernet\n                    ',
#   'Inspur',
#   '48,000',
#   '748.2',
#   '1,766.4'],
#  ['463',
#   'Internet Service (B)',
#   'China',
#   'Inspur TS10000, Xeon E5-2670v3 12C 2.3GHz, 10G Ethernet\n                    ',
#   'Inspur',
#   '48,000',
#   '748.2',
#   '1,766.4'],
#  ['464',
#   'Service Provider T',
#   'China',
#   'Inspur TS10000, Xeon E5-2670v3 12C 2.3GHz, 10G Ethernet\n                    ',
#   'Inspur',
#   '48,000',
#   '748.2',
#   '1,766.4'],
#  ['465',
#   'Manufacturing Company A',
#   'Germany',
#   'FusionServer CH140 V3 Cluster, Xeon E5-2680 v4/E5-2680v3 12C 2.5GHz, Infiniband FDR\n                    ',
#   'Huawei Technologies Co., Ltd.',
#   '35,480',
#   '747.7',
#   '1,419.2',
#   '574'],
#  ['466',
#   'Central China Normal University',
#   'China',
#   'Inspur TS10000 HPC Cluster System',
#   ' - Inspur TS10000, Xeon Gold 6126 12C 2.6GHz, NVIDIA Tesla V100, Infiniband EDR\n                    ',
#   'Inspur',
#   '11,952',
#   '746.1',
#   '1,080.0'],
#  ['467',
#   'Software Company (M)',
#   'United States',
#   'Cluster Platform DL360, Xeon E5-2673v3 12C 2.4GHz, 10G Ethernet\n                    ',
#   'HPE',
#   '32,832',
#   '746.1',
#   '1,260.7'],
#  ['468',
#   'Center for Computational Sciences, University of Tsukuba',
#   'Japan',
#   'COMA (PACS-IX)',
#   ' - Cray CS300 1027GR, Intel Xeon E5-2670v2  10C 2.500GHz, Infiniband FDR, Intel Xeon Phi 7110P\n                    ',
#   'Cray Inc.',
#   '55,664',
#   '746.0',
#   '998.5',
#   '366'],
#  ['469',
#   'Government',
#   'China',
#   'ImageSystem',
#   ' - Sugon Cluster W580I, Xeon Gold 5118 12C 2.3GHz, NVIDIA Tesla P100, Infiniband FDR\n                    ',
#   'Sugon',
#   '15,872',
#   '745.9',
#   '1,288.4',
#   '150'],
#  ['470',
#   'Internet Company A',
#   'China',
#   'Internet Company A R1',
#   ' - Lenovo RD550, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '34,560',
#   '745.4',
#   '1,382.4'],
#  ['471',
#   'Service Provider',
#   'Korea, South',
#   'Cluster Platform DL380, Xeon E5-2680v4 14C 2.4GHz, 10G Ethernet\n                    ',
#   'HPE',
#   '32,200',
#   '744.0',
#   '1,236.5'],
#  ['472',
#   'Government',
#   'China',
#   'Sugon TC6000, Xeon E5-2680v4 14C 2.4GHz, 10G Ethernet\n                    ',
#   'Sugon',
#   '39,200',
#   '742.4',
#   '1,505.3',
#   '588'],
#  ['473',
#   'Internet Company (I)',
#   'China',
#   'video_system',
#   ' - Sugon W580-G20, Xeon E5-2650v4 12C 2.2GHz, 10G Ethernet\n                    ',
#   'Sugon',
#   '43,200',
#   '742.3',
#   '1,520.6',
#   '540'],
#  ['474',
#   'Internet Company',
#   'China',
#   'Sugon TC6000, Xeon E5-2650v4 12C 2.2GHz, 10G Ethernet\n                    ',
#   'Sugon',
#   '43,200',
#   '741.8',
#   '1,520.6',
#   '900'],
#  ['475',
#   'National Institute for Materials Science',
#   'Japan',
#   'Numerical Materials Simulator',
#   ' - SGI ICE X, Xeon E5-2680v3 12C 2.5GHz, Infiniband FDR\n                    ',
#   'HPE',
#   '25,056',
#   '741.7',
#   '1,002.2',
#   '405'],
#  ['476',
#   'Internet Service (B)',
#   'China',
#   'Lenovo RD550, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '38,400',
#   '740.4',
#   '1,536.0'],
#  ['477',
#   'University of Florida',
#   'United States',
#   'HiperGator 2.0',
#   ' - PowerEdge C6320, Xeon E5-2698v3 16C 2.3GHz, Infiniband\n                    ',
#   'Dell EMC',
#   '29,184',
#   '738.1',
#   '1,074.0',
#   '384'],
#  ['478',
#   'LASG/Institute of Atmospheric Physics, CAS',
#   'China',
#   'Earth System Numerical Simulator',
#   ' - Sugon Cluster TC4600E, Xeon E5-2680v3 12C 2.5GHz, Infiniband FDR\n                    ',
#   'Sugon',
#   '24,912',
#   '738.0',
#   '996.5',
#   '540'],
#  ['479',
#   'Service Provider T',
#   'China',
#   'Internet Company T V1',
#   ' - Lenovo RD450, Xeon E5-2670v3 12C 2.3GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '38,400',
#   '734.8',
#   '1,413.1'],
#  ['480',
#   'Government',
#   'China',
#   'Sugon TC6000, Xeon E5-2690v4 14C 2.6GHz, 10G Ethernet\n                    ',
#   'Sugon',
#   '35,840',
#   '734.7',
#   '1,490.9',
#   '576'],
#  ['481',
#   'Manufacturing Company B',
#   'Germany',
#   'FusionServer X6800/XH620 V3 Cluster, Xeon E5-2650v4 12C 2.2GHz, Infiniband QDR\n                    ',
#   'Huawei Technologies Co., Ltd.',
#   '27,960',
#   '733.9',
#   '984.2',
#   '336'],
#  ['482',
#   'Internet Company',
#   'China',
#   'Sugon TC6000, Xeon E5-2620v4 8C 2.1GHz, 10G Ethernet\n                    ',
#   'Sugon',
#   '44,800',
#   '733.7',
#   '1,505.3',
#   '650'],
#  ['483',
#   'Government',
#   'China',
#   'HC2000 Cluster, Xeon E5-2620v3 6C 2.4GHz, Infiniband FDR, NVIDIA Tesla K40\n                    ',
#   'Sugon',
#   '14,400',
#   '731.2',
#   '1,236.2',
#   '400'],
#  ['484',
#   'Information Technology Company (P)',
#   'China',
#   'Cluster Platform DL360, Xeon E5-2650v4 12C 2.2GHz, 10G Ethernet\n                    ',
#   'HPE',
#   '34,896',
#   '731.2',
#   '1,228.3'],
#  ['485',
#   'Telecom Company',
#   'China',
#   'CMCluster',
#   ' - Sugon TC6000, Xeon Gold 5118 12C 2.3GHz, 10G Ethernet\n                    ',
#   'Sugon',
#   '40,320',
#   '730.7',
#   '1,483.8',
#   '504'],
#  ['486',
#   'Internet Service A',
#   'China',
#   'Inspur TS10000 HPC Server, Intel Xeon E5-2650v2  8C 2.6GHz, 10G Ethernet, NVIDIA Tesla K40\n                    ',
#   'Inspur',
#   '15,640',
#   '730.1',
#   '1,085.6',
#   '225'],
#  ['487',
#   'Internet Company',
#   'China',
#   'Sugon TC6000, Xeon E5-2650v3 10C 2.3GHz, 10G Ethernet\n                    ',
#   'Sugon',
#   '40,000',
#   '725.0',
#   '1,472.0',
#   '990'],
#  ['488',
#   'Internet Company A',
#   'China',
#   'Lenovo RD450, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '36,864',
#   '721.1',
#   '1,474.6'],
#  ['489',
#   'Internet Company A',
#   'China',
#   'Lenovo RD450, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '36,864',
#   '721.1',
#   '1,474.6'],
#  ['490',
#   'Internet Company A',
#   'China',
#   'Lenovo RD450, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '36,864',
#   '721.1',
#   '1,474.6'],
#  ['491',
#   'Internet Company A',
#   'China',
#   'Lenovo RD450, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '36,864',
#   '721.1',
#   '1,474.6'],
#  ['492',
#   'Internet Company A',
#   'China',
#   'Lenovo RD450, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '36,864',
#   '721.1',
#   '1,474.6'],
#  ['493',
#   'Internet Company A',
#   'China',
#   'Lenovo RD450, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '36,864',
#   '721.1',
#   '1,474.6'],
#  ['494',
#   'Internet Company A',
#   'China',
#   'Lenovo RD450, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '36,864',
#   '721.1',
#   '1,474.6'],
#  ['495',
#   'Internet Company A',
#   'China',
#   'Lenovo RD450, Xeon E5-2682v4 16C 2.5GHz, 10G Ethernet\n                    ',
#   'Lenovo',
#   '36,864',
#   '721.1',
#   '1,474.6'],
#  ['496',
#   'Indian Institute of Tropical Meteorology',
#   'India',
#   'iDataPlex DX360M4, Xeon E5-2670 8C 2.600GHz, Infiniband FDR\n                    ',
#   'IBM',
#   '38,016',
#   '719.2',
#   '790.7',
#   '790'],
#  ['497',
#   'DOE/SC/Argonne National Laboratory',
#   'United States',
#   'Cetus',
#   ' - BlueGene/Q, Power BQC 16C 1.600GHz, Custom Interconnect\n                    ',
#   'IBM',
#   '65,536',
#   '715.6',
#   '838.9',
#   '329'],
#  ['498',
#   'EDF R&D',
#   'France',
#   'Zumbrota',
#   ' - BlueGene/Q, Power BQC 16C 1.60GHz, Custom\n                    ',
#   'IBM',
#   '65,536',
#   '715.6',
#   '838.9',
#   '329'],
#  ['499',
#   'SOSCIP/LKSAVI/University of Toronto',
#   'Canada',
#   'BGQ',
#   ' - BlueGene/Q, Power BQC 16C 1.600GHz, Custom Interconnect\n                    ',
#   'IBM',
#   '65,536',
#   '715.6',
#   '838.9',
#   '329'],
#  ['500',
#   'Swiss National Supercomputing Centre (CSCS)',
#   'Switzerland',
#   'EPFL Blue Brain IV',
#   ' - BlueGene/Q, Power BQC 16C 1.600GHz, Custom Interconnect\n                    ',
#   'IBM',
#   '65,536',
#   '715.6',
#   '838.9',
#   '329']]

# %%
#a) Using Python with BeautifulSoup, extract the data from the Web site

 #  and create a csv dataset containing that data.

import pandas as pd

columns = ['Rank','Site','Country','System1','System2','System3','Cores','Rmax','Rpeak','Power']



df = pd.DataFrame(data[1:], columns=columns)
df_CoresToPower=df.iloc[:,6:10]
df4=df_CoresToPower

# %%
df.to_csv('output.csv')#output of the BeautifulSoup is copied to OUTPUT.CSV

# %%
#b) Clean & explore the dataset, producing summary statistics

 #  for Cores, RMax, RPeak, and Power.

df.isnull().sum()#No of NA'S in each column in the dataframe.
# Out:
# Rank         4
# Site         4
# Country      4
# System1      4
# System2      4
# System3      4
# Cores        4
# Rmax         4
# Rpeak      128
# Power      311
# dtype: int64

# %%
df4['Cores'].describe()#summary statistics for Cores Column
# Out:
# count        500
# unique       345
# top       57,600
# freq          27
# Name: Cores, dtype: object

# %%
df4.isnull().sum()#No of NA'S in each column in the dataframe.
# Out:
# Cores      4
# Rmax       4
# Rpeak    128
# Power    311
# dtype: int64

# %%
df4.fillna(method ='ffill', inplace = True) #using ffill method, which fills the data using the previous  value in the same column.
# Out:
# C:\Users\mitta\Anaconda3\lib\site-packages\pandas\core\frame.py:3035: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
df4.isnull().sum()#there are no missing values and filled by previous column values.
# Out:
# Cores    0
# Rmax     0
# Rpeak    0
# Power    0
# dtype: int64

# %%
df4.describe()
# Out:
#          Cores     Rmax    Rpeak  Power
# count      504      504      504    504
# unique     345      367      292    164
# top     57,600  1,649.1  2,119.7  3,747
# freq        28       26       26     27

# %%
df4['Cores'].describe()
# Out:
# count        504
# unique       345
# top       57,600
# freq          28
# Name: Cores, dtype: object

# %%
df4['Rmax'].describe()
# Out:
# count         504
# unique        367
# top       1,649.1
# freq           26
# Name: Rmax, dtype: object

# %%
df4['Rpeak'].describe()
# Out:
# count         504
# unique        292
# top       2,119.7
# freq           26
# Name: Rpeak, dtype: object

# %%
df4['Power'].describe()
# Out:
# count       504
# unique      164
# top       3,747
# freq         27
# Name: Power, dtype: object

# %%
#c) Display and explain the relationship between 

#Cores and RPeak(theretical performance)

#Cores and Power(How much power does it consume)
x=df4['Cores']
y=df4['Rpeak']
plt.scatter(x,y,color='red')
plt.xlabel('Cores')
plt.ylabel('Rpeak')
plt.title("No of Cores vs RPeak")
plt.show()
#as number of cores increased the Rpeak performance also improved for some system and they follow a linear regression.
#and there are also other systems, where the number of cores are less and theoretical performance is high.
#and there are also other systems, where the number of cores are high and theoretical performance is low.
#therefore all kinds of data is present.

# %%
#df4.plot(kind='scatter',df4['Cores'],df4['Power'])
#country.plot(kind="bar",fill="black",color="orange")

N = 50
a = df4['Cores']
b = df4['Power']
colors = np.random.rand(N)
#area = (10 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(a, b)
plt.xlabel('Cores')
plt.ylabel('Power')
plt.title("No of Cores vs Power")
plt.show()

#Even in this case, there are all kinds of data, 
#1.When no of cores increase Power also increased, which follows linear regression.
#2.when no of cores high and increasing, some systems have less power consumption.
#3.There are also systems, when no of cores are less and also systems having high power.

# %%
#d) [Challenge problem, bonus 10 extra points]:

#Display summary statistics and visualizations for the Country data.
country=pd.DataFrame(df.Country.value_counts())
country
# Out:
#                 Country
# China               206
# United States       124
# Japan                36
# United Kingdom       22
# Germany              21
# France               18
# Netherlands           9
# Korea, South          7
# Ireland               7
# Canada                6
# India                 5
# Italy                 5
# Australia             5
# Russia                4
# Saudi Arabia          4
# Poland                4
# Sweden                3
# Switzerland           3
# Spain                 2
# Singapore             2
# South Africa          1
# Brazil                1
# Taiwan                1
# Finland               1
# Norway                1
# New Zealand           1
# Czech Republic        1

# %%
country.describe()#summary statistics for country data.
# Out:
#           Country
# count   27.000000
# mean    18.518519
# std     44.492325
# min      1.000000
# 25%      1.500000
# 50%      4.000000
# 75%      8.000000
# max    206.000000

# %%
country.plot(kind="bar",fill="black",color="orange")#Visualizations for country data.
